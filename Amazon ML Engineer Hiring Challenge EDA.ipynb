# %% [markdown]
# # **<center><u> Exploratory Data Analysis</u></center>**

# %% [markdown]
# # Importing important Libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data:

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1             13.168425                       9.447662
# 1          csid_2             17.092979                       7.329056
# 2          csid_3             17.505334                       5.143676
# 3          csid_4             31.423381                       4.917740
# 4          csid_5             11.909502                       4.237073
# ...           ...                   ...                            ...
# 10733  csid_10734             23.672615                       6.701514
# 10734  csid_10735             25.673028                       6.497796
# 10735  csid_10736             31.676844                       7.799880
# 10736  csid_10737             28.441780                       5.588302
# 10737  csid_10738             20.663035                       4.478301
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# ...

# %%
test
# Out:
#      customer_id  customer_visit_score  customer_product_search_score  \
# 0     csid_10739             22.500174                       3.702145
# 1     csid_10740             13.225950                       3.600102
# 2     csid_10741             14.603376                       5.084047
# 3     csid_10742             26.149905                       3.025501
# 4     csid_10743             19.810630                       5.020400
# ...          ...                   ...                            ...
# 7155  csid_17894             18.164300                       7.240835
# 7156  csid_17895             25.363705                       4.881059
# 7157  csid_17896             11.160720                       5.019859
# 7158  csid_17897             17.140020                       9.269037
# 7159  csid_17898             10.698835                      12.173331
#
#       customer_ctr_score  customer_stay_score  customer_frequency_score  \
# ...

# %% [markdown]
# # Data Preprocessing:

# %%
# Let's make a copy of both test and train data:
tr = train.copy()
te = test.copy()

# %% [markdown]
# ## 1. For Train Data:

# %%
# let's take a look at the missing data
train.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score       42
# customer_ctr_score                   0
# customer_stay_score                 37
# customer_frequency_score             0
# customer_product_variation_score    46
# customer_order_score                66
# customer_affinity_score              0
# customer_active_segment             23
# X1                                  37
# customer_category                    0
# dtype: int64

# %%
tr.describe()
# Out:
#        customer_visit_score  customer_product_search_score  \
# count          10738.000000                   10696.000000
# mean              19.060941                       5.274847
# std                7.419609                       1.882559
# min                0.568965                      -0.161940
# 25%               13.518021                       3.971587
# 50%               18.774109                       5.218479
# 75%               24.501719                       6.520364
# max               47.306691                      16.638243
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# count        10738.000000         10701.000000              10738.000000
# mean             0.175912             0.374230                  2.376895
# std              0.372829             1.222031                  5.601911
# min             -0.547989            -0.462494                  0.028575
# ...

# %%
# Filling missing data for numerical feature
tr['customer_product_search_score'].fillna(tr['customer_product_search_score'].mean(),inplace=True)
tr['customer_stay_score'].fillna(tr['customer_stay_score'].mean(),inplace=True)
tr['customer_product_variation_score'].fillna(tr['customer_product_variation_score'].median(),inplace=True)
tr['customer_order_score'].fillna(tr['customer_order_score'].median(),inplace=True)

# %%
tr.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score        0
# customer_ctr_score                   0
# customer_stay_score                  0
# customer_frequency_score             0
# customer_product_variation_score     0
# customer_order_score                 0
# customer_affinity_score              0
# customer_active_segment             23
# X1                                  37
# customer_category                    0
# dtype: int64

# %%
# making a new copy 
tr1 = tr.copy()

# %%
# Following feature I am filling after careful data analysis beforehand
for i in range(len(tr1['customer_visit_score'])):
    if tr1['customer_active_segment'][i] is np.nan:
        if tr1['customer_visit_score'][i] <= 10:
            tr1['customer_active_segment'][i] =  'D'
        elif tr1['customer_visit_score'][i] > 10 and tr1['customer_visit_score'][i] <= 30:
            tr1['customer_active_segment'][i] = 'B'
        elif tr1['customer_visit_score'][i] >= 30:
            tr1['customer_active_segment'][i] = 'AA'
    else:
        pass

# %%
tr1.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score        0
# customer_ctr_score                   0
# customer_stay_score                  0
# customer_frequency_score             0
# customer_product_variation_score     0
# customer_order_score                 0
# customer_affinity_score              0
# customer_active_segment              0
# X1                                  37
# customer_category                    0
# dtype: int64

# %%
for i in range(len(tr1['customer_order_score'])):
    if tr1['X1'][i] is np.nan:
        if tr1['customer_order_score'][i] <= 3 and tr1['customer_order_score'][i] >2:
            tr1['X1'][i] =  'BA'
        if tr1['customer_order_score'][i] <= 2:
            tr1['X1'][i] =  'F'
        elif tr1['customer_order_score'][i] <= 4 and tr1['customer_visit_score'][i] > 3:
            tr1['X1'][i] = 'A'
        elif tr1['customer_order_score'][i] > 4 and tr1['customer_visit_score'][i] <= 6:
            tr1['X1'][i] = 'AA'
        elif tr1['customer_order_score'][i] > 6:
            tr1['X1'][i] = 'E'
    else:
        pass

# %%
tr1.isna().sum()
# Out:
# customer_id                         0
# customer_visit_score                0
# customer_product_search_score       0
# customer_ctr_score                  0
# customer_stay_score                 0
# customer_frequency_score            0
# customer_product_variation_score    0
# customer_order_score                0
# customer_affinity_score             0
# customer_active_segment             0
# X1                                  6
# customer_category                   0
# dtype: int64

# %%
tr1['X1'].fillna('A',inplace=True)

# %%
tr1.isna().sum()
# Out:
# customer_id                         0
# customer_visit_score                0
# customer_product_search_score       0
# customer_ctr_score                  0
# customer_stay_score                 0
# customer_frequency_score            0
# customer_product_variation_score    0
# customer_order_score                0
# customer_affinity_score             0
# customer_active_segment             0
# X1                                  0
# customer_category                   0
# dtype: int64

# %% [markdown]
# ### So, now our train data is clean.

# %% [markdown]
# ## 2. For Test Data:

# %%
# let's take a look at a missing data
te.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score       29
# customer_ctr_score                   0
# customer_stay_score                 16
# customer_frequency_score             0
# customer_product_variation_score    43
# customer_order_score                41
# customer_affinity_score              0
# customer_active_segment             12
# X1                                  25
# dtype: int64

# %%
# Filling missing data for numerical feature
te['customer_product_search_score'].fillna(te['customer_product_search_score'].mean(),inplace=True)
te['customer_stay_score'].fillna(te['customer_stay_score'].mean(),inplace=True)
te['customer_product_variation_score'].fillna(te['customer_product_variation_score'].median(),inplace=True)
te['customer_order_score'].fillna(te['customer_order_score'].median(),inplace=True)

# %%
te.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score        0
# customer_ctr_score                   0
# customer_stay_score                  0
# customer_frequency_score             0
# customer_product_variation_score     0
# customer_order_score                 0
# customer_affinity_score              0
# customer_active_segment             12
# X1                                  25
# dtype: int64

# %%
# making a new copy
te1 = te.copy()

# %%
for i in range(len(te1['customer_order_score'])):
    if te1['X1'][i] is np.nan:
        if te1['customer_order_score'][i] <= 3 and te1['customer_order_score'][i] >2:
            te1['X1'][i] =  'BA'
        if te1['customer_order_score'][i] <= 2:
            te1['X1'][i] =  'F'
        elif te1['customer_order_score'][i] <= 4 and te1['customer_visit_score'][i] > 3:
            te1['X1'][i] = 'A'
        elif te1['customer_order_score'][i] > 4 and te1['customer_visit_score'][i] <= 6:
            te1['X1'][i] = 'AA'
        elif te1['customer_order_score'][i] > 6:
            te1['X1'][i] = 'E'
    else:
        pass

# %%
te1.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score        0
# customer_ctr_score                   0
# customer_stay_score                  0
# customer_frequency_score             0
# customer_product_variation_score     0
# customer_order_score                 0
# customer_affinity_score              0
# customer_active_segment             12
# X1                                   4
# dtype: int64

# %%
te1['X1'].fillna('A',inplace=True)

# %%
te1.isna().sum()
# Out:
# customer_id                          0
# customer_visit_score                 0
# customer_product_search_score        0
# customer_ctr_score                   0
# customer_stay_score                  0
# customer_frequency_score             0
# customer_product_variation_score     0
# customer_order_score                 0
# customer_affinity_score              0
# customer_active_segment             12
# X1                                   0
# dtype: int64

# %%
for i in range(len(te1['customer_visit_score'])):
    if te1['customer_active_segment'][i] is np.nan:
        if te1['customer_visit_score'][i] <= 10:
            te1['customer_active_segment'][i] =  'D'
        elif te1['customer_visit_score'][i] > 10 and te1['customer_visit_score'][i] <= 30:
            te1['customer_active_segment'][i] = 'B'
        elif te1['customer_visit_score'][i] >= 30:
            te1['customer_active_segment'][i] = 'AA'
    else:
        pass

# %%
te1.isna().sum()
# Out:
# customer_id                         0
# customer_visit_score                0
# customer_product_search_score       0
# customer_ctr_score                  0
# customer_stay_score                 0
# customer_frequency_score            0
# customer_product_variation_score    0
# customer_order_score                0
# customer_affinity_score             0
# customer_active_segment             0
# X1                                  0
# dtype: int64

# %% [markdown]
# ### So, now our test data is also clean.

# %% [markdown]
# <h1></h1>

# %% [markdown]
# # DATA ANALYSIS:

# %%
from IPython.display import Image
Image("img.png")

# %% [markdown]
# ## 1. Correlation between the features:

# %%
cor = tr1.corr()
a = (12, 10)

fig, ax = plt.subplots(figsize=a)
sns.heatmap(cor).set_title("Correlation Matrix",fontsize=50)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ### What we got from correlation matrix:
# #### 1. *Positvely correlated:-*
#
# * **customer_ctr_score is positively correlated to customer_stay_score:** Customer who stays more in the website are more likely to click more searched link.
#
#
# * **customer_frequency_score is positively correlated to customer_product_variation_score:** customer whose frequency of visit in one day is more are more likely to searche variety of products.
#
#
# * **customer_affinity_score is positively correlated to customer_order_score:** customers who like the website loves to order more from the website. Trust is there.
#
#
# * **ustomer_ctr_score is positively correlated to customer_product_variation_score:** customer who like to seacher variety of the product do more search by cliking more links.
#
#
# #### 2. *Negetively correlated:*
#
# * **customer_order_score is negatively correlated to customer_product_variation_score:** customer who searches variety product usually do not buy them. Customer are just checking the products.
#
#
# * **customer_visit_score is negatively correlated to customer_stay_score:** Customer who visit the sites regularly do not stay for long. The reason behide this can be the just come for a little to see some deals in the product and then left. Since they visit regularly they do not need to stay more time to know the deals.

# %% [markdown]
# <h1></h1>

# %% [markdown]
# ## 2. Customer active segment:

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=tr1, x="customer_visit_score", y="customer_stay_score", 
                hue="customer_active_segment").set_title("customer_visit_score vs customer_stay_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_visit_score vs customer_stay_score')

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=train, x="customer_visit_score", y="customer_order_score",
                hue="customer_active_segment").set_title("customer_visit_score vs customer_order_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_visit_score vs customer_order_score')

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=train, x="customer_visit_score", y="customer_product_search_score",
                hue="customer_active_segment").set_title("customer_visit_score vs customer_product_search_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_visit_score vs customer_product_search_score')

# %% [markdown]
# ### From above plots we estimate:
# * **D category:** This type of customer do not visit website often but when visited they tend to stay more time in the website. I think this customers usualy come in the big deal season.
#
#
# * **B category:** This type of customer visit the website more then D.
#
#
# * **C category:** I think its the mixture of both B and D category customers because paterns are like that only.
#
#
# * **AA and A category:** This category customer are a regular visitor of the website and also stay less. I think the come regularly just to check the daily deals, etc.

# %% [markdown]
# <h1></h1>

# %% [markdown]
# ## 3. X1 (Anonymized feature):

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=train, x="customer_order_score", y="customer_affinity_score", 
                hue="X1").set_title("customer_order_score vs customer_affinity_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_order_score vs customer_affinity_score')

# %% [markdown]
# ### From the above plots we can state that categories are according to the trust of customer to the website. plot shows with increase in  customer_order_score, customer_affinity_score is increasing.
#
# #### Rank:
#
# * **1 -  E category**
# * **2 -  AA category**
# * **3 -  A category**
# * **4 -  F category**
# * **5 -  BA category**

# %% [markdown]
# <h1></h1>

# %% [markdown]
# # 4. Customer Category:

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=tr1, x="customer_stay_score", y="customer_ctr_score",
                hue="customer_category").set_title("customer_stay_score vs customer_ctr_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_stay_score vs customer_ctr_score')

# %% [markdown]
# ### From the graph b/w customer_stay_score and customer_ctr_score: It states that 1 category are of those customer whose ctr_score is more then 0.5 means those customers who search more links. 0 category customers are those who are do not search more links.

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=tr1, x="customer_visit_score", y="customer_stay_score",
                hue="customer_category").set_title("customer_visit_score vs customer_stay_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_visit_score vs customer_stay_score')

# %% [markdown]
# ### From above plot we can say that customers who stay more on the website are more likely to be in 1 category.

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=train, x="customer_visit_score", y="customer_order_score",
                hue="customer_category").set_title("customer_visit_score vs customer_order_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_visit_score vs customer_order_score')

# %%
a= (15,10)
fig, ax = plt.subplots(figsize = a)
sns.scatterplot(data=train, x="customer_visit_score", y="customer_affinity_score",
                hue="customer_category").set_title("customer_visit_score vs customer_affinity_score",fontsize=30)
# Out:
# Text(0.5, 1.0, 'customer_visit_score vs customer_affinity_score')

# %% [markdown]
# ### From above plot we can say that 1 category customers do not have mush affinity towards the website. Therefore these type of customer can be  new customers to the website.

# %% [markdown]
# <h1></h1>

# %% [markdown]
# # *Question to be solved:*

# %% [markdown]
# ## Q1. What are the pros & cons of recommendation by this approach?

# %% [markdown]
# ### *Pros:-*
# * **Every customer is classified according to the there affinity towards the wesite and activity. This type of approach make one wesite easily give different type of benefits according to there group.**
#
#
# * **Every group members will have some similarity which can be used to recommend the other members of the same group.**
#
#
# * **This approach have easily identified the groups according to the activeness of customer in the website. Now this activeness score can be used to attract the customer who are less active with some vouchers so that they again come to the website again and use it for buying the products.**

# %% [markdown]
# ### *Cons:-*
# * **The main challenge is to gain customer trust. We can see from the data that loyal customers are very less. Its not easy to  increase the numbers of loyal Customers as every person have there own perception.**
#
#
# * **Variety of people is must for any recommendation system. To make a great recommendation system we not only need high volume of data as as high variety of data.**

# %% [markdown]
# <h1></h1>

# %% [markdown]
# ## Q2. Propose an architecture that will work more efficiently when building a recommendation engine for an e-commerce platform

# %%
Image("img1.jpeg")

# %% [markdown]
# ### The above recommendation methods will be best for the e-commerce platform.
